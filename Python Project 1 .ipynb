# %% [markdown]
# Python Project 1: Exploratory Data Analysis of NYC Public Schools-Comparative Analysis **Python Fall 2023-Imran Khan Jasmin Benjamin

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Project 1 DOE NYC Public School Regents:
#RESEARCH QUESTION:HOW DOES TOWNSEND HARRIS HIGH SCHOOL COMPARES TO THE SCHOOL IN ITS DISTRICT IN
# IN TERMS OF COLLEGE READINESS?
#Townsend Harris High School(Queens) vs. District 25 High Schools (Queens)


#1 the goal of this project is to analyze student test performance

#2 pick one school in this dataset as an initial comparison point

#3 pick one feature/measure/score (college readiness)

#4 compare above school to schools in the entire dataset, schools in a
#particular borough, OR schools in a particular district - you only need
#to do one additional comparison point (but you’re welcome to do
#more comparisons if you feel compelled to do so)

#5 the analysis should include some descriptive statistics(mean,median,count)

#6 the analysis should include one cleaning task (or more)(renaming column,subset,missing value)

#7 the analysis should include one visualization (or more), which answers the question,use plot function

# Dictionary link: https://data.cityofnewyork.us/Education/2014-15-To-2016-17-School-Level-NYC-Regents-Report/csps-2ne9

#Bkooklyn=K, Bronx=X, Queens=Q, Manhattan=M, Staten Island=R

# %%
#Question 1: Analyze data:
#The first five rows of dataframe:
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
#returns last five rows from dataframe:
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
#Returns tuple of shape (Rows, columns) of dataframe/series:
df.shape
# Out:
# (212331, 15)

# %%
#column labels in dataframe:
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
#Five point summary/generates descriptive statistics for dataFrame: 
#note-std=standard deviation, 50%=median
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
#calculates the total number of missing (null) values in dataframe:
df.isnull().sum().sum()
# Out:
# 10

# %%
#Question 2: Pick any school in this dataset as an initial comparison point?
#Townsend Harris High School(Queens) vs District 25 High Schools (Queens) College Readiness

# %%
#Question 2:Pick any school in this dataset as an initial comparison point?
df_Townsend=df[df['School Name'].str.contains('Townsend Harris High School')]

# %%
df_Townsend
# Out:
#        School DBN                  School Name School Level  \
# 14321      25Q525  Townsend Harris High School  High school
# 14322      25Q525  Townsend Harris High School  High school
# 14323      25Q525  Townsend Harris High School  High school
# 14324      25Q525  Townsend Harris High School  High school
# 14325      25Q525  Townsend Harris High School  High school
# ...           ...                          ...          ...
# 193186     25Q525  Townsend Harris High School  High school
# 193187     25Q525  Townsend Harris High School  High school
# 193188     25Q525  Townsend Harris High School  High school
# 193189     25Q525  Townsend Harris High School  High school
# 193190     25Q525  Townsend Harris High School  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 14321         Algebra2/Trigonometry  2015           270       90.7
# 14322         Algebra2/Trigonometry  2016           292       93.6
# ...

# %%
#Question 3:pick one feature/measure/score 
df_Townsend.describe()
# Out:
#               Year  Total Tested
# count   373.000000    373.000000
# mean   2015.946381     95.790885
# std       0.827822     99.170670
# min    2015.000000      1.000000
# 25%    2015.000000     12.000000
# 50%    2016.000000     52.000000
# 75%    2017.000000    180.000000
# max    2017.000000    315.000000

# %%
#Question 3:pick one feature/measure/score (Number Scoring college readiness)
df_Townsend1 = df_Townsend[['School Name','Regents Exam','Year','Mean Score','Number Scoring CR']]

# %%
df_Townsend1
# Out:
#                         School Name                 Regents Exam  Year  \
# 14321   Townsend Harris High School        Algebra2/Trigonometry  2015
# 14322   Townsend Harris High School        Algebra2/Trigonometry  2016
# 14323   Townsend Harris High School          Common Core Algebra  2015
# 14324   Townsend Harris High School          Common Core Algebra  2016
# 14325   Townsend Harris High School          Common Core Algebra  2017
# ...                             ...                          ...   ...
# 193186  Townsend Harris High School  U.S. History and Government  2017
# 193187  Townsend Harris High School  U.S. History and Government  2017
# 193188  Townsend Harris High School  U.S. History and Government  2017
# 193189  Townsend Harris High School  U.S. History and Government  2017
# 193190  Townsend Harris High School  U.S. History and Government  2017
#
#        Mean Score Number Scoring CR
# 14321        90.7               243
# 14322        93.6               279
# ...

# %%
#Question 5:the analysis should include some descriptive statistics(mean,median,count)
df_Townsend1.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                         School Name                 Regents Exam  Year  \
# 14321   Townsend Harris High School        Algebra2/Trigonometry  2015
# 14322   Townsend Harris High School        Algebra2/Trigonometry  2016
# 14323   Townsend Harris High School          Common Core Algebra  2015
# 14324   Townsend Harris High School          Common Core Algebra  2016
# 14325   Townsend Harris High School          Common Core Algebra  2017
# ...                             ...                          ...   ...
# 193186  Townsend Harris High School  U.S. History and Government  2017
# 193187  Townsend Harris High School  U.S. History and Government  2017
# 193188  Townsend Harris High School  U.S. History and Government  2017
# 193189  Townsend Harris High School  U.S. History and Government  2017
# 193190  Townsend Harris High School  U.S. History and Government  2017
#
#        Mean Score Number Scoring CR
# ...

# %%
#Question 6:the analysis should include one cleaning task (or more)(renaming column,subset,missing value)
missing_value_mask = df_Townsend1['Number Scoring CR'] == 'na'

# %%
total_missing_values = missing_value_mask.sum()
print(f"Total missing values: {total_missing_values}")
# Out:
# Total missing values: 222

# %%
df_Townsend1_cleaned = df_Townsend1[~missing_value_mask] 
#print 
df_Townsend1_cleaned
# Out:
#                         School Name           Regents Exam  Year Mean Score  \
# 14321   Townsend Harris High School  Algebra2/Trigonometry  2015       90.7
# 14322   Townsend Harris High School  Algebra2/Trigonometry  2016       93.6
# 14323   Townsend Harris High School    Common Core Algebra  2015         78
# 14324   Townsend Harris High School    Common Core Algebra  2016       88.7
# 14325   Townsend Harris High School    Common Core Algebra  2017       89.7
# ...                             ...                    ...   ...        ...
# 193105  Townsend Harris High School               Geometry  2015       94.1
# 193106  Townsend Harris High School               Geometry  2015       92.4
# 193107  Townsend Harris High School               Geometry  2015         94
# 193108  Townsend Harris High School               Geometry  2015         89
# 193109  Townsend Harris High School               Geometry  2015       93.3
#
#        Number Scoring CR
# 14321                243
# ...

# %%
df_Townsend1_cleaned.dropna(subset=['Number Scoring CR'],inplace=True)
# Out:
# C:\Users\Jasmin Benjamin\AppData\Local\Temp\ipykernel_964\1725804936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Townsend1_cleaned.dropna(subset=['Number Scoring CR'],inplace=True)

# %%
df_Townsend1_cleaned.shape
# Out:
# (151, 5)

# %%
df_Townsend1_cleaned.describe()
# Out:
#               Year
# count   151.000000
# mean   2015.933775
# std       0.821940
# min    2015.000000
# 25%    2015.000000
# 50%    2016.000000
# 75%    2017.000000
# max    2017.000000

# %%
df_Townsend1_cleaned.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                         School Name           Regents Exam  Year Mean Score  \
# 14321   Townsend Harris High School  Algebra2/Trigonometry  2015       90.7
# 14322   Townsend Harris High School  Algebra2/Trigonometry  2016       93.6
# 14323   Townsend Harris High School    Common Core Algebra  2015         78
# 14324   Townsend Harris High School    Common Core Algebra  2016       88.7
# 14325   Townsend Harris High School    Common Core Algebra  2017       89.7
# ...                             ...                    ...   ...        ...
# 193105  Townsend Harris High School               Geometry  2015       94.1
# 193106  Townsend Harris High School               Geometry  2015       92.4
# 193107  Townsend Harris High School               Geometry  2015         94
# 193108  Townsend Harris High School               Geometry  2015         89
# ...

# %%
df_Townsend1_cleaned.dropna()
# Out:
#                         School Name           Regents Exam  Year Mean Score  \
# 14321   Townsend Harris High School  Algebra2/Trigonometry  2015       90.7
# 14322   Townsend Harris High School  Algebra2/Trigonometry  2016       93.6
# 14323   Townsend Harris High School    Common Core Algebra  2015         78
# 14324   Townsend Harris High School    Common Core Algebra  2016       88.7
# 14325   Townsend Harris High School    Common Core Algebra  2017       89.7
# ...                             ...                    ...   ...        ...
# 193105  Townsend Harris High School               Geometry  2015       94.1
# 193106  Townsend Harris High School               Geometry  2015       92.4
# 193107  Townsend Harris High School               Geometry  2015         94
# 193108  Townsend Harris High School               Geometry  2015         89
# 193109  Townsend Harris High School               Geometry  2015       93.3
#
#        Number Scoring CR
# 14321                243
# ...

# %%
#total number of missing value
df_Townsend1_cleaned.isnull().sum().sum()
# Out:
# 0

# %%
#Question 4:Removed Townsend Harris from District 25 in order to compare School Vs. District
District_25 = df[df['School DBN'].str.startswith("25Q")& (df['School DBN'] != "25Q525")]

# %%
#top rows in District 25, after removal of Townsend Harris HS
District_25.head()
# Out:
#       School DBN            School Name                     School Level  \
# 13946     25Q025  I.S. 025 Adrien Block  Junior High-Intermediate-Middle
# 13947     25Q025  I.S. 025 Adrien Block  Junior High-Intermediate-Middle
# 13948     25Q025  I.S. 025 Adrien Block  Junior High-Intermediate-Middle
# 13949     25Q025  I.S. 025 Adrien Block  Junior High-Intermediate-Middle
# 13950     25Q025  I.S. 025 Adrien Block  Junior High-Intermediate-Middle
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 13946  Common Core Algebra  2015            66       83.5
# 13947  Common Core Algebra  2016            66       88.9
# 13948  Common Core Algebra  2017            63       90.3
# 13949   Living Environment  2015            66       90.5
# 13950   Living Environment  2016            67       89.6
#
#       Number Scoring Below 65 Percent Scoring Below 65  \
# 13946                       0                        0
# 13947                       0                        0
# ...

# %%
#Provide dimension of District 25
District_25.shape
# Out:
# (5206, 15)

# %%
#descriptive statistic of District 25
District_25.describe()
# Out:
#               Year  Total Tested
# count  5206.000000   5206.000000
# mean   2015.966193     61.744141
# std       0.796733    118.382887
# min    2015.000000      1.000000
# 25%    2015.000000      7.000000
# 50%    2016.000000     25.000000
# 75%    2017.000000     63.000000
# max    2017.000000   1384.000000

# %%
#Testing to make sure Townsend Harris is removed from data
District_25['School Name'].unique()
# Out:
# array(['I.S. 025 Adrien Block', 'P.S. 164 Queens Valley',
#        'J.H.S. 185 Edward Bleeker', 'J.H.S. 189 Daniel Carter Beard',
#        'J.H.S. 194 William Carr',
#        'P.S./M.S. 200 - The Pomonok School & STAR Academy',
#        'P.S. 219 Paul Klapper', 'I.S. 237', 'Veritas Academy',
#        'Queens High School for Language Studies',
#        'I.S. 250 The Robert F. Kennedy Community Middle Sc',
#        'Queens School of Inquiry, The',
#        'Flushing International High School',
#        'East-West School of International Studies',
#        'World Journalism Preparatory: A College Board Scho',
#        'BELL Academy', 'John Bowne High School', 'Flushing High School',
#        'Flushing Yabc',
#        'The Queens College School for Math, Science and Te',
#        'Queens Academy High School',
#        'Robert F. Kennedy Community High School',
#        'North Queens Community High School'], dtype=object)

# %%
#pick one feature/measure/score (Number Scoring college readiness
District_25 = District_25[['School Name','Regents Exam','Year','Mean Score','Number Scoring CR']]

# %%
#print
District_25.head()
# Out:
#                  School Name         Regents Exam  Year Mean Score  \
# 13946  I.S. 025 Adrien Block  Common Core Algebra  2015       83.5
# 13947  I.S. 025 Adrien Block  Common Core Algebra  2016       88.9
# 13948  I.S. 025 Adrien Block  Common Core Algebra  2017       90.3
# 13949  I.S. 025 Adrien Block   Living Environment  2015       90.5
# 13950  I.S. 025 Adrien Block   Living Environment  2016       89.6
#
#       Number Scoring CR
# 13946                64
# 13947                66
# 13948                63
# 13949                na
# 13950                na

# %%
#the analysis should include some descriptive statistics(mean,median,count)
District_25.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                                School Name                 Regents Exam  Year  \
# 13946                I.S. 025 Adrien Block          Common Core Algebra  2015
# 13947                I.S. 025 Adrien Block          Common Core Algebra  2016
# 13948                I.S. 025 Adrien Block          Common Core Algebra  2017
# 13949                I.S. 025 Adrien Block           Living Environment  2015
# 13950                I.S. 025 Adrien Block           Living Environment  2016
# ...                                    ...                          ...   ...
# 193523  North Queens Community High School  U.S. History and Government  2016
# 193524  North Queens Community High School  U.S. History and Government  2017
# 193525  North Queens Community High School  U.S. History and Government  2017
# 193526  North Queens Community High School  U.S. History and Government  2017
# ...

# %%
#total of missing values of District 25 data
total_missing_values = District_25['Number Scoring CR'].isna().sum()
print(f"Total missing values: {total_missing_values}")
# Out:
# Total missing values: 0

# %%
#missing values of District 25 cleaned
District_25_cleaned = District_25.dropna(subset=['Number Scoring CR'])

# %%
District_25_cleaned
# Out:
#                                School Name                 Regents Exam  Year  \
# 13946                I.S. 025 Adrien Block          Common Core Algebra  2015
# 13947                I.S. 025 Adrien Block          Common Core Algebra  2016
# 13948                I.S. 025 Adrien Block          Common Core Algebra  2017
# 13949                I.S. 025 Adrien Block           Living Environment  2015
# 13950                I.S. 025 Adrien Block           Living Environment  2016
# ...                                    ...                          ...   ...
# 193523  North Queens Community High School  U.S. History and Government  2016
# 193524  North Queens Community High School  U.S. History and Government  2017
# 193525  North Queens Community High School  U.S. History and Government  2017
# 193526  North Queens Community High School  U.S. History and Government  2017
# 193527  North Queens Community High School  U.S. History and Government  2017
#
# ...

# %%
#Dropping of missing values
District_25_cleaned.dropna(subset=['Number Scoring CR'],inplace=True)

# %%
#print
District_25
# Out:
#                                School Name                 Regents Exam  Year  \
# 13946                I.S. 025 Adrien Block          Common Core Algebra  2015
# 13947                I.S. 025 Adrien Block          Common Core Algebra  2016
# 13948                I.S. 025 Adrien Block          Common Core Algebra  2017
# 13949                I.S. 025 Adrien Block           Living Environment  2015
# 13950                I.S. 025 Adrien Block           Living Environment  2016
# ...                                    ...                          ...   ...
# 193523  North Queens Community High School  U.S. History and Government  2016
# 193524  North Queens Community High School  U.S. History and Government  2017
# 193525  North Queens Community High School  U.S. History and Government  2017
# 193526  North Queens Community High School  U.S. History and Government  2017
# 193527  North Queens Community High School  U.S. History and Government  2017
#
# ...

# %%
#Dropped clean data
District_25_cleaned.dropna()
# Out:
#                                School Name                 Regents Exam  Year  \
# 13946                I.S. 025 Adrien Block          Common Core Algebra  2015
# 13947                I.S. 025 Adrien Block          Common Core Algebra  2016
# 13948                I.S. 025 Adrien Block          Common Core Algebra  2017
# 13949                I.S. 025 Adrien Block           Living Environment  2015
# 13950                I.S. 025 Adrien Block           Living Environment  2016
# ...                                    ...                          ...   ...
# 193523  North Queens Community High School  U.S. History and Government  2016
# 193524  North Queens Community High School  U.S. History and Government  2017
# 193525  North Queens Community High School  U.S. History and Government  2017
# 193526  North Queens Community High School  U.S. History and Government  2017
# 193527  North Queens Community High School  U.S. History and Government  2017
#
# ...

# %%
District_25_cleaned.head()
# Out:
#                  School Name         Regents Exam  Year Mean Score  \
# 13946  I.S. 025 Adrien Block  Common Core Algebra  2015       83.5
# 13947  I.S. 025 Adrien Block  Common Core Algebra  2016       88.9
# 13948  I.S. 025 Adrien Block  Common Core Algebra  2017       90.3
# 13949  I.S. 025 Adrien Block   Living Environment  2015       90.5
# 13950  I.S. 025 Adrien Block   Living Environment  2016       89.6
#
#       Number Scoring CR
# 13946                64
# 13947                66
# 13948                63
# 13949                na
# 13950                na

# %%
District_25_cleaned.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                                School Name                 Regents Exam  Year  \
# 13946                I.S. 025 Adrien Block          Common Core Algebra  2015
# 13947                I.S. 025 Adrien Block          Common Core Algebra  2016
# 13948                I.S. 025 Adrien Block          Common Core Algebra  2017
# 13949                I.S. 025 Adrien Block           Living Environment  2015
# 13950                I.S. 025 Adrien Block           Living Environment  2016
# ...                                    ...                          ...   ...
# 193523  North Queens Community High School  U.S. History and Government  2016
# 193524  North Queens Community High School  U.S. History and Government  2017
# 193525  North Queens Community High School  U.S. History and Government  2017
# 193526  North Queens Community High School  U.S. History and Government  2017
# ...

# %%
#total number of missing value
District_25_cleaned.isnull().sum().sum()
# Out:
# 0

# %%
#Question 7-Data Visualization
plt.plot(District_25_cleaned['Number Scoring CR'], label='District 25')
plt.plot(df_Townsend1_cleaned['Number Scoring CR'], label='Townsend 1')
plt.xlabel('Index')
plt.ylabel('Number Scoring CR')
plt.title('Comparison of Number Scoring CR')
plt.legend()
plt.show()

# %%
# Plot the Number Scoring CR column for each dataframe as a scatter plot
plt.scatter(District_25_cleaned.index, District_25_cleaned['Number Scoring CR'], label='District 25')
plt.scatter(df_Townsend1_cleaned.index, df_Townsend1_cleaned['Number Scoring CR'], label='Townsend 1')

# Add labels, title, and legend
plt.xlabel('Index')
plt.ylabel('Number Scoring CR')
plt.title('Comparison of Number Scoring CR')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Townsend Harris High School 'Number Scoring College Readiness' had an average score of 95.790885
# compared to District 25 average score of 61.744141. Townsend Harris High School had 34.046744 higher
# score than District 25 in Queens.
